# %%
import pandas as pd

# %%
import joblib

# Load the feature selector
feature_selector = joblib.load(r"C:\Users\User\Downloads\selected_features.pkl")

# Check what type of object it is
print(type(feature_selector))

# Print the contents to understand its structure
print(feature_selector)
# Out:
# <class 'list'>
# ...

# %%
# Load your dataset (replace with actual file path)
df = pd.read_csv("your_data.csv")

# Get dataset columns
dataset_features = df.columns.tolist()

# Check if all selected features exist in the dataset
missing_features = [feature for feature in selected_features if feature not in dataset_features]

if missing_features:
    print("Missing features:", missing_features)
else:
    print("All selected features are present in the dataset.")

# %%
import pandas as pd

df = pd.read_csv(r"D:\Django\material-dashboard-django-master\2016_data.csv", on_bad_lines="skip")

df.shape  # Check how many rows were loaded
# Out:
# (8208, 51)

# %%
df.iloc[8200:8210]
# Out:
#       respondent_id   age  gender education_level residence_type  \
# 8200       23151664  36.0    male       secondary          urban
# 8201       23148250  37.0    male         primary          rural
# 8202       22902257  24.0  female        tertiary          urban
# 8203       22706687  28.0  female       secondary          urban
# 8204       23538836  30.0  female       secondary          urban
# 8205       23533373  35.0    male         primary          urban
# 8206       22559735  35.0  female        tertiary          rural
# 8207       23892905  23.0  female       secondary          rural
#
#                    marital_status relationship_to_hh  region  \
# 8200  married/living with partner               head  nyanza
# 8201           divorced/separated               head  nyanza
# 8202                       single               head  nyanza
# 8203  married/living with partner             spouse  nyanza
# 8204           divorced/separated               head  nyanza
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# respondent_id               0
# age                         0
# gender                      0
# education_level             0
# residence_type              0
# marital_status              0
# relationship_to_hh          0
# region                      0
# population_weight           0
# mobile_money_registered     0
# savings_mobile_banking      0
# bank_account_current        0
# bank_account_savings        0
# bank_account_everyday       0
# postbank_account            0
# bank_overdraft              0
# debit_card                  0
# credit_card                 0
# savings_microfinance        0
# savings_sacco               0
# savings_group_friends       0
# savings_family_friend       0
# savings_secret_place        0
# loan_bank                   0
# loan_mobile_banking         0
# loan_sacco                  0
# loan_microfinance           0
# loan_shylock                0
# loan_group_chama            0
# loan_govt                   0
# loan_employer               0
# ...
